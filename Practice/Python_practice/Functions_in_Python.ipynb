# %% [markdown]
# Beginner-Friendly Python Function Practice Questions
#
# 1. Write a function that takes two numbers as input and returns their sum.
#
# 2. Write a function that takes a string as input and returns the string reversed.
#
# 3. Write a function that checks if a given number is even or odd. Return `True` for even and `False` for odd.
#
# 4. Write a function that takes a list of numbers as input and returns the largest number in the list.
#
# 5. Write a function that takes a list of numbers and returns the average of the numbers.
#
# 6. Write a function that takes a string and a character, and returns the number of times the character appears in the string.
#
# 7. Write a function that takes a number as input and returns `True` if the number is prime and `False` otherwise.
#
# 8. Write a function that takes a list of words and returns alist of the lengths of those words.
#
# 9. Write a function that takes a list of numbers and returns a new list with only the even numbers.
#
# 10. Write a function that takes two strings and checks if they are anagrams (contain the same characters in a different order).
#
# 11. Write a function that takes a list and an item, and returns `True` if the item is in the list and `False` otherwise.
#
# 12. Write a function that takes a string and returns `True` if it is a palindrome and `False` otherwise.
#
# 13. Write a function that takes a number and returns its factorial.
#
# 14. Write a function that takes a list of numbers and returns the second largest number.
#
# 15. Write a function that takes two lists and returns a list of elements that are common to both lists.
#
# 16. Write a function that takes a string and returns the most frequent character in the string.
#
# 17. Write a function that takes a list of numbers and returns a list with duplicates removed.
#
# 18. Write a function that takes a number and returns the Fibonacci sequence up to that number.
#
# 19. Write a function that takes a list of dictionaries (e.g., `[{"name": "Alice"}, {"name": "Bob"}]`) and a key, and returns a list of values corresponding to that key.
#
# 20. Write a function that takes a number and returns the sum of its digits.
#
# 21. Write a function that takes a string and returns the string with all vowels removed.
#
# 22. Write a function that takes a list of numbers and returns the product of all the numbers.
#
# 23. Write a function that takes a string and a word, and returns the number of times the word appears in the string.
#
# 24. Write a function that takes a list of numbers and returns a list of numbers squared.
#
# 25. Write a function that takes a list of strings and returns the string with the most characters.
#
# 26. Write a function that takes a temperature in Celsius and converts it to Fahrenheit.
#
# 27. Write a function that takes a list of numbers and returns `True` if the list is sorted in ascending order, and `False` otherwise.
#
# 28. Write a function that takes a list of numbers and returns the median.
#
# 29. Write a function that takes a string and returns the number of uppercase and lowercase letters in the string.
#
# 30. Write a function that takes a year and checks if it is a leap year.
#
# 31. Write a function that takes a list of numbers and returns the sum of all odd numbers in the list.
#
# 32. Write a function that takes a sentence and returns the number of words in the sentence.
#
# 33. Write a function that takes a number and returns its binary representation as a string.
#
# 34. Write a function that takes a list of numbers and returns the difference between the largest and smallest numbers.
#
# 35. Write a function that takes a list of tuples (e.g., `[(1, 2), (3, 4)]`) and returns a list of their sums (e.g., `[3, 7]`).
#
# 36. Write a function that takes a list of strings and returns a new list with all strings converted to uppercase.
#
# 37. Write a function that takes a list of numbers and returns `True` if all numbers are positive, and `False` otherwise.
#
# 38. Write a function that takes a string and returns a dictionary with the count of each character in the string.
#
# 39. Write a function that takes a list of numbers and returns the first repeated number, or `None` if there are no repeats.
#
# 40. Write a function that takes a string and returns the number of unique characters in the string.
#
# 41. Write a function that takes a list of integers and returns a list with the integers sorted in descending order.
#
# 42. Write a function that takes a number and returns `True` if it is a perfect square, and `False` otherwise.
#
# 43. Write a function that takes a string and returns a new string with the first and last characters swapped.
#
# 44. Write a function that takes two numbers and returns the greatest common divisor (GCD) of the two numbers.
#
# 45. Write a function that takes a list of numbers and returns a new list with each number incremented by 1.
#
# 46. Write a function that takes a string and returns the longest word in the string.
#
# 47. Write a function that takes a list of numbers and a target sum, and returns a tuple of two numbers from the list that add up to the target, or `None` if no such pair exists.
#
# 48. Write a function that takes a list of numbers and returns the number of prime numbers in the list.
#
# 49. Write a function that takes a string and a character, and returns a new string with all occurrences of the character removed.
#
# 50. Write a function that takes a number and returns the sum of all multiples of 3 or 5 below that number.
